# %%
import requests
from bs4 import BeautifulSoup

URL = "https://firstratedata.com/i/stock/AAPL"
page = requests.get(URL)

#print(page.text)
soup = BeautifulSoup(page.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-1682792-22"></script>
# <script>
#         window.dataLayer = window.dataLayer || [];
#         function gtag() { dataLayer.push(arguments); }
#         gtag('js', new Date());
#
#         gtag('config', 'UA-1682792-22');
#     </script>
# <!-- Required meta tags -->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <!-- Twitter -->
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="600" property="og:image:height"/>
# <title>Download Historical Apple (AAPL) Stock Price Data (20 Years Data)</title>
# <meta content="Download 17 years of intraday Apple(AAPL) data : 1-minute, 5-minute, 30-minute, and 1-hour bars (open/high/low/close/volume) and tick-level data. Data is aggregated from 22 exchanges (including dark-pools). Includes out-of-hours trading data." name="description"/>
# <link href="/Content/Theme1/asia_min_full.css" rel="stylesheet"/>
# <!-- vendor css -->
# <!-- azia CSS -->
# <!-- Facebook Pixel Code -->
# <!-- End Facebook Pixel Code -->
# <!--    Hotjar Tracking Code for https://firstratedata.com -->
# <script data-popup-closed="onFSPopupClosed" data-storefront="firstratedata.onfastspring.com/popup-frd1" id="fsc-api" src="https://d1f8f9xcsvx3ha.cloudfront.net/sbl/0.8.3/fastspring-builder.min.js" type="text/javascript">
# </script>
# <script>
#         function onFSPopupClosed(orderReference) {
#
#             if (orderReference) {
#                 console.log(orderReference.reference);
#                 fastspring.builder.reset();
#                 window.location.replace("https://firstratedata.com/purchase-success?fsID=" + orderReference.reference);
#             } else {
#
#
#                 console.log("QUIT");
#             }
#         }
#     </script>
# <script>
#         function addAndCheckout(fastspringProduct) {
#             fastspring.builder.add(fastspringProduct, function () {
#                 fastspring.builder.checkout();
#             });
#         }
#     </script>
# <!-- Hotjar Tracking Code for https://firstratedata.com -->
# <script>
#         (function (h, o, t, j, a, r) {
#             h.hj = h.hj || function () { (h.hj.q = h.hj.q || []).push(arguments) };
#             h._hjSettings = { hjid: 1861716, hjsv: 6 };
#             a = o.getElementsByTagName('head')[0];
#             r = o.createElement('script'); r.async = 1;
#             r.src = t + h._hjSettings.hjid + j + h._hjSettings.hjsv;
#             a.appendChild(r);
#         })(window, document, 'https://static.hotjar.com/c/hotjar-', '.js?sv=');
#     </script>
# </head>
# <body class="az-minimal">
# <div class="az-header">
# <div class="container">
# <div class="az-header-left">
# <a class="az-logo" href="/"><span></span>FirstRate Data</a>
# <a class="az-header-menu-icon d-lg-none" href="" id="azMenuShow"><span></span></a>
# </div><!-- az-header-left -->
# <div class="az-header-menu">
# <div class="az-header-menu-header">
# <a class="az-logo" href="/" style="font-size:16pt;"><span></span> FirstRate Data</a>
# <a class="close" href="">×</a>
# </div><!-- az-header-menu-header -->
# <ul class="nav">
# <li class="nav-item spacing">
# <a class="nav-link with-sub" href="">Bundles</a>
# <div class="az-menu-sub">
# <nav class="nav">
# <a class="nav-link" href="/cb/1/complete-us-stocks-index-etf-futures">Complete Bundle (Stock, Futures, ETF, Index, Crypto)</a><a class="nav-link" href="/cb/4/complete-stocks-etf">Complete Stock and ETF Bundle </a>
# <a class="nav-link" href="/b/1/sp500-historical-intraday-stocks-bundle">S&amp;P500 Stocks (880 tickers)</a><a class="nav-link" href="/b/2/nasdaq100-historical-intraday-stocks-bundle">NASDAQ 100 Stocks (183 tickers)</a><a class="nav-link" href="/b/9/djia-dji-indu-historical-intraday">Dow Jones Industrial  (47 tickers)</a><a class="nav-link" href="/b/22/stock-complete-historical-intraday">Stocks Complete  </a><a class="nav-link" href="/b/24/sp100-stocks-tick">S&amp;P 100 Stocks Tick Data </a><a class="nav-link" href="/b/4/etf-50-historical-intraday">ETFs - 50 Most Liquid ETFs</a><a class="nav-link" href="/b/17/etf-complete-historical-intraday">ETF Complete - 950 Most Liquid ETFs</a><a class="nav-link" href="/b/27/etf50-ticks">ETFs - 50 Most Liquid ETFs [Tick Data]</a><a class="nav-link" href="/b/8/us-index-historic-intraday">US Indices (115 tickers)</a><a class="nav-link" href="/b/12/international-historical-index">International Indices (10 tickers)</a><a class="nav-link" href="/b/20/fx-majors">FX Majors - 10 Major FX Tickers</a><a class="nav-link" href="/b/29/futures-most-active">Futures Most Active (100 Most Active Futures)</a><a class="nav-link" href="/b/31/crypto-active">Crypto Most Active (50 Most Active Tickers)</a><a class="nav-link" href="/b/34/crypto-active-tick">Crypto - 50 Most Active [Tick Data]</a>
# </nav><br/><span style="font-weight:bold; "> <a class="nav-link" href="/bundle/all">ALL Bundles...</a></span>
# </div><!-- az-menu-sub -->
# </li>
# <li class="nav-item spacing">
# <a class="nav-link with-sub" href=""> Stocks</a>
# <div class="az-menu-sub">
# <nav class="nav">
# <a class="nav-link" href="/it/stock/A-D">A - D</a>
# <a class="nav-link" href="/it/stock/E-I">E - I</a>
# <a class="nav-link" href="/it/stock/J-N">J - N</a>
# <a class="nav-link" href="/it/stock/O-R">O - R</a>
# <a class="nav-link" href="/it/stock/S-Z">S - Z</a>
# </nav>
# <br/><span style="font-weight:bold; "> <a class="nav-link" href="/it/stock">ALL Intraday Stock Data...</a></span>
# </div><!-- az-menu-sub -->
# </li>
# <li class="nav-item spacing">
# <a class="nav-link with-sub" href="">Futures</a>
# <div class="az-menu-sub">
# <nav class="nav">
# <a class="nav-link" href="/i/futures/ES">E-Mini S&amp;P 500 Futures (ES)</a><a class="nav-link" href="/i/futures/NQ">E-mini Nasdaq-100 Futures
#  (NQ)</a><a class="nav-link" href="/i/futures/BTC">Bitcoin Futures (BTC)</a><a class="nav-link" href="/i/futures/CL">Crude Oil WTI Futures (CL)</a><a class="nav-link" href="/i/futures/GC">Gold Futures (GC)</a><a class="nav-link" href="/i/futures/VX">VIX Futures (VX)</a><a class="nav-link" href="/i/futures/ZN">10-Year Treasury Note Futures (ZN)</a> <br/>
# <span style="font-weight:bold; "> <a class="nav-link" href="/it/futures">All Futures...</a></span>
# </nav>
# </div><!-- az-menu-sub -->
# </li>
# <li class="nav-item spacing">
# <a class="nav-link with-sub" href="">Indices</a>
# <div class="az-menu-sub">
# <nav class="nav">
# <a class="nav-link" href="/i/index/SPX">S&amp;P 500 (SPX)</a><a class="nav-link" href="/i/index/VIX">Cboe Volatility Index (VIX)</a><a class="nav-link" href="/i/index/DJI">Dow Jones Industrial Average (DJI)</a><a class="nav-link" href="/i/index/NDX">Nasdaq 100 (NDX)</a><a class="nav-link" href="/i/index/UKX">FTSE 100 (UKX)</a> </nav><br/><span style="font-weight:bold; "> <a class="nav-link" href="/it/index">ALL Intraday Index Data...</a></span>
# </div><!-- az-menu-sub -->
# </li>
# <li class="nav-item spacing">
# <a class="nav-link with-sub" href="">ETFs</a>
# <div class="az-menu-sub">
# <nav class="nav">
# <a class="nav-link" href="/i/etf/DIA">DIA (SPDR DOW JONES INDUSTRIAL AVERAGE)</a><a class="nav-link" href="/i/etf/IWM">IWM (ISHARES RUSSELL 2000 INDEX)</a><a class="nav-link" href="/i/etf/SPY">SPY (SPDR S&amp;P 500)</a><a class="nav-link" href="/i/etf/VXX">VXX (IPATH S&amp;P 500 VIX SHORT-TERM FUTURES)</a><br/>
# <span style="font-weight:bold; "> <a class="nav-link" href="/it/etf">ALL Intraday ETF Data...</a></span>
# </nav>
# </div><!-- az-menu-sub -->
# </li>
# <li class="nav-item spacing">
# <a class="nav-link with-sub" href="">Crypto/FX</a>
# <div class="az-menu-sub">
# <nav class="nav">
# <a class="nav-link" href="/i/crypto/BTC">Bitcoin (BTC)</a><a class="nav-link" href="/i/crypto/ETH">Ethereum (ETH)</a><a class="nav-link" href="/i/crypto/LTC">Litecoin (LTC)</a><a class="nav-link" href="/i/crypto/DOGE">DogeCoin (DOGE)</a><a class="nav-link" href="/i/crypto/BCH">Bitcoin Cash (BCH)</a><a class="nav-link" href="/i/crypto/EOS">EOS (EOS)</a>
# <br/><span style="font-weight:bold; "> <a class="nav-link" href="/it/crypto">ALL Historical Cryptocurrency Data...</a></span>
# <hr/>
# <a class="nav-link" href="/i/fx/USDJPY">USD JPY</a><a class="nav-link" href="/i/fx/GBPUSD">GBP USD</a><a class="nav-link" href="/i/fx/EURUSD">EUR USD</a><a class="nav-link" href="/i/fx/AUDUSD">AUD USD</a> <br/><span style="font-weight:bold; "> <a class="nav-link" href="/it/fx">ALL Intraday FX Data...</a></span>
# </nav>
# </div><!-- az-menu-sub -->
# </li>
# <li class="nav-item spacing">
# <a class="nav-link with-sub" href=""> About</a>
# <div class="az-menu-sub">
# <nav class="nav">
# <a class="nav-link" href="/about/firstrate-data">About Us</a>
# <a class="nav-link" href="/blog">Blog</a>
# <a class="nav-link" href="/about/FAQ">FAQ</a>
# <a class="nav-link" href="/about/careers">Careers</a>
# <a class="nav-link" href="/about/contact">Contact</a>
# </nav>
# </div><!-- az-menu-sub -->
# </li>
# </ul>
# </div><!-- az-header-menu -->
# <div class="az-header-right">
# </div><!-- az-header-right -->
# </div><!-- container -->
# </div><!-- az-header -->
# <div class="az-content pd-y-20">
# <div class="container">
# <div class="az-content-body">
# <div style="margin:0 0 25px 0; font-size:9pt;">
# <a href="/">Home</a>        /
# <a href="/it/stock">Stock Main</a>        /
# Intraday  Apple (AAPL) Data
# </div>
# <h1 class="az-content-title-minimal" style="margin:10px 0 23px 0;">
#
#
#     Historical Apple (AAPL) Stock Price Data
#
#
#
# </h1>
# <div class="row">
# <div class="col-lg-8 ht-lg-100p">
# <div class="card card-dashboard-one">
# <div class="card-header" style="margin:0 0 20px 0; border-bottom:1px solid grey;">
# <div>
# <h6 class="card-title">
#                             Apple (AAPL)
#
#                             Datasets
#                         </h6>
# <p class="card-text"></p>
# </div>
# <ul class="nav nav-pills mb-1" id="pills-tab" role="tablist">
# <li class="nav-item">
# <a class="nav-link show active2" href="/i/stock/AAPL">Intraday Bars</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/i/stock/AAPL/tick">Tick</a>
# </li>
# </ul>
# </div>
# <div class="card-body" style="margin:0 0 0 0;">
# <div class="tab-content" id="pills-tabContent" style="padding:0 0 0 25px;">
# <div aria-labelledby="pills-Mins1-tab" class="tab-pane show active" id="pills-Mins1" role="tabpanel">
# <table class="table">
# <thead>
# <tr>
# <th align="right"><div style="margin:0 0 0 15px;">Frequency</div></th>
# <th>Start Date</th>
# <th>End Date</th>
# <th style="font-weight:bold; font-size:11pt; border:none;">
# <div style="padding:0 0 0 15px;border:none;">
# <button onclick="addAndCheckout('x-aapl-stock-ds-2280');" style="background-color:#6772E5;color:#FFF;padding:8px 12px;border:0;border-radius:4px;font-size:1em">
#                                                             Buy Now
#
#
#                                                                 <span data-fsc-item-path="x-xyl-stock-ds-2871" data-fsc-item-unitprice=""></span>
# </button>
# </div>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>
# <h6>
# <button aria-expanded="false" aria-haspopup="true" class="btn btn-outline-primary dropdown-toggle" data-toggle="dropdown" id="dropdownMenuButton" type="button">
#                                                         Intraday Bars
#                                                     </button>
# <div aria-labelledby="dropdownMenuButton" class="dropdown-menu tx-13">
# <a class="dropdown-item" href="/i/stock/AAPL/tick">Tick</a>
# </div>
# </h6>
# </td>
# <td> <h6>3-Jan-2005</h6></td>
# <td><h6>3-May-2022</h6></td>
# <td style="padding:0 0 0 35px; border:none;">
# <a class="btn btn-link btn-sm" href="https://firstratedata.com/_data/_deploy/AAPL_stock_sample.zip" rel="nofollow" style="margin:0 0 0 5px; padding: 0 0 0 0; font-size:10pt; font-weight:bold; ">Download Sample</a>
# </td>
# </tr>
# </tbody>
# </table>
# <span> Data is collected and aggregated from 25 exchanges (including dark pools).</span> <p><br/>Data is updated weekly and all customers receive 1 month of free updates (thereafter, an annual subscription of $49.95 is required for the updates) </p>
# <span>This dataset contains 1-minute, 5-minute, 30-minute and 1-hour bars   (open/high/low/close</span><span>/volume</span><span>)</span>
# <span>for AAPL (Apple). </span>
# <br/><br/><div>Out-of-hours trades are included. Prices are adjusted for splits and dividends.</div>
# <hr style="width:50%;"/>
# <h5>This Dataset is Available in the below Bundles :</h5><br/>
# <div class="" style="margin:0 0 15px 0;">
# <div class="media">
# <div class="media-body">
# <span style="font-weight:bold;  font-size:11pt;"><a href="/cb/1/complete-us-stocks-index-etf-futures">Complete Bundle (Stock, Futures, ETF, Index, Crypto)</a> |  6000 Tickers </span>
# </div>
# </div>
# </div>
# <div class="" style="margin:0 0 15px 0;">
# <div class="media">
# <div class="media-body">
# <span style="font-weight:bold;  font-size:11pt;"><a href="/cb/4/complete-stocks-etf">Complete Stock and ETF Bundle </a> |  5715 Tickers </span>
# </div>
# </div>
# </div>
# </div>
# <div class="" style="margin:0 0 15px 0;">
# <div class="media">
# <div class="media-body">
# <span style="font-weight:bold;  font-size:11pt;"><a href="/b/1/sp500-historical-intraday-stocks-bundle">S&amp;P500 Historical Intraday Prices Bundle</a> |  885 Tickers </span>
# </div>
# </div>
# </div>
# <div class="" style="margin:0 0 15px 0;">
# <div class="media">
# <div class="media-body">
# <span style="font-weight:bold;  font-size:11pt;"><a href="/b/2/nasdaq100-historical-intraday-stocks-bundle">NASDAQ100 Historical Dataset</a> |  182 Tickers </span>
# </div>
# </div>
# </div>
# <div class="" style="margin:0 0 15px 0;">
# <div class="media">
# <div class="media-body">
# <span style="font-weight:bold;  font-size:11pt;"><a href="/b/9/djia-dji-indu-historical-intraday">Dow Jones Industrials Historical Dataset</a> |  47 Tickers </span>
# </div>
# </div>
# </div>
# <div class="" style="margin:0 0 15px 0;">
# <div class="media">
# <div class="media-body">
# <span style="font-weight:bold;  font-size:11pt;"><a href="/b/22/stock-complete-historical-intraday">Stocks Complete  </a> |  4764 Tickers </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div style="font-style:italic; font-size:9pt; margin:25px 25px 0 25px;">Our intraday data and tick data are sourced direct from major exchanges and tested for completeness and consistency. The files are in comma-separated (csv) format, zipped and available for immediate download</div>
# </div><!-- card -->
# </div><!-- col -->
# <div class="col-lg-4 mg-t-20 mg-lg-t-0">
# </div><!--col -->
# </div><!-- row -->
# <div style="font-size:x-small; float:right;">2280 | </div>
# </div>
# </div>
# </div><!-- az-content -->
# <div class="az-footer ht-40">
# <div class="container pd-t-0-f ht-100p">
# <span>© 2022 FirstRate Data LLC | <b>support@firstratedata.com</b></span>
# </div>
# </div><!-- az-footer -->
# <script crossorigin="anonymous" integrity="sha256-/xUj+3OJU5yExlq6GSYGSHk7tPXikynS7ogEvDej/m4=" src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/js/bootstrap.min.js"></script>
# <script src="/Content/Theme1/js/azia.js"></script>
# </body>
# </html>

# %%
single_stock = "https://firstratedata.com/i/stock/"
all_stocks = "https://firstratedata.com/it/stock"
tickers = ['TSLA', ]
